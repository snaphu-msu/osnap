# %%
import stir_to_mesa as stm

# %%
stir_data = stm.read_stir_checkpoint("stir2_14may19_s25.0_alpha1.25_hdf5_chk_0216")
# For testing purposes, we're using a kepler progenitor now. Once we have a MESA model passed through STIR, we can switch.
prog_data = stm.read_kepler_progenitor(25.0)
#prog_data = stm.read_mesa_output('progenitors/mesa/CC.mod')
star = stm.Star(stir_data, prog_data)
# Out:
# yt : [WARNING  ] 2025-03-14 13:29:36,533 Extending phi dimension to 2PI + left edge.
# yt : [WARNING  ] 2025-03-14 13:29:36,534 Extending theta dimension to PI + left edge.
# yt : [INFO     ] 2025-03-14 13:29:36,593 Parameters: current_time              = 2.112453642154664
# yt : [INFO     ] 2025-03-14 13:29:36,594 Parameters: domain_dimensions         = [240   1   1]
# yt : [INFO     ] 2025-03-14 13:29:36,595 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-14 13:29:36,595 Parameters: domain_right_edge         = [1.50000000e+09 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2025-03-14 13:29:36,596 Parameters: cosmological_simulation   = 0
# /mnt/ffs24/home/jdelker/main/projects/osnap/progs/prog_io.py:132: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   network = pd.read_csv(filepath, delim_whitespace=True)
# ...

# %%
#write_mesa_input(stir_output, 1)
