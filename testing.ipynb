# %%
from stir_to_mesa import *
convert("s15_2e9", 1.3, 0.8)
# Out:
# yt : [WARNING  ] 2025-03-20 17:09:02,483 Extending phi dimension to 2PI + left edge.
# yt : [WARNING  ] 2025-03-20 17:09:02,484 Extending theta dimension to PI + left edge.
# yt : [INFO     ] 2025-03-20 17:09:02,537 Parameters: current_time              = 2.4410002554725243
# yt : [INFO     ] 2025-03-20 17:09:02,538 Parameters: domain_dimensions         = [240   1   1]
# yt : [INFO     ] 2025-03-20 17:09:02,538 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-20 17:09:02,539 Parameters: domain_right_edge         = [5.20000000e+09 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2025-03-20 17:09:02,539 Parameters: cosmological_simulation   = 0
# Successfully created/updated './output/s15_2e9_a1.3_stir_output.mod'
