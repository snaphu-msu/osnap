# %%
import stir_to_mesa as stm

# %%
stir_data = stm.read_stir_output("tardis_test_hdf5_chk_0029")
prog_data = stm.read_mesa_progenitor("progenitors/mesa/profile2.data", "progenitors/mesa/profile2.mod")
#prog_data = stm.read_kepler_progenitor(25.0)
star = stm.Star(stir_data, prog_data)
star.write_mesa_model()
# Out:
# yt : [WARNING  ] 2025-03-20 09:13:36,260 Extending phi dimension to 2PI + left edge.
# yt : [WARNING  ] 2025-03-20 09:13:36,261 Extending theta dimension to PI + left edge.
# yt : [INFO     ] 2025-03-20 09:13:36,316 Parameters: current_time              = 1.2392389576437883
# yt : [INFO     ] 2025-03-20 09:13:36,317 Parameters: domain_dimensions         = [240   1   1]
# yt : [INFO     ] 2025-03-20 09:13:36,317 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-20 09:13:36,318 Parameters: domain_right_edge         = [5.20000000e+09 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2025-03-20 09:13:36,318 Parameters: cosmological_simulation   = 0
# Successfully created/updated 'stir_output.mod'
