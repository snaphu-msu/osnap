# %%
from stir_to_mesa import *

# %%
convert(model_name = "80_single", stir_alpha = 1.25, stir_portion = 0.8, plotted_profiles=["DEFAULT"])
# Out:
# yt : [WARNING  ] 2025-03-28 13:25:45,228 Extending phi dimension to 2PI + left edge.
# yt : [WARNING  ] 2025-03-28 13:25:45,229 Extending theta dimension to PI + left edge.
# yt : [INFO     ] 2025-03-28 13:25:45,283 Parameters: current_time              = 1.450000098920163
# yt : [INFO     ] 2025-03-28 13:25:45,284 Parameters: domain_dimensions         = [240   1   1]
# yt : [INFO     ] 2025-03-28 13:25:45,284 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-28 13:25:45,285 Parameters: domain_right_edge         = [1.50000000e+09 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2025-03-28 13:25:45,286 Parameters: cosmological_simulation   = 0
# Successfully created/updated './output/80_single_a1.25_stir_output.mod'
