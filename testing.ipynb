# %%
import stir_to_mesa as stm

# %%
# Progenitor and STIR run information
zams_mass = 15
alpha = 1.25

# Building paths for input and output
stir_path = "tardis_final_125_withnucleo_hdf5_plt_cnt_1606"
stir_output = f"s{zams_mass}_a{alpha}_stir_output.mod"
mesa_mod = f"progenitors/mesa/s{zams_mass}.mod"
mesa_profile = f"progenitors/mesa/s{zams_mass}.data"

# %%
stir_data = stm.read_stir_output(stir_path)
prog_data = stm.read_mesa_progenitor(mesa_profile, mesa_mod)
star = stm.Star(stir_data, prog_data)
star.write_mesa_model(stir_output)
# Out:
# yt : [WARNING  ] 2025-03-20 11:11:33,567 Extending phi dimension to 2PI + left edge.
# yt : [WARNING  ] 2025-03-20 11:11:33,568 Extending theta dimension to PI + left edge.
# yt : [INFO     ] 2025-03-20 11:11:33,616 Parameters: current_time              = 1.606000052525753
# yt : [INFO     ] 2025-03-20 11:11:33,617 Parameters: domain_dimensions         = [240   1   1]
# yt : [INFO     ] 2025-03-20 11:11:33,617 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-20 11:11:33,618 Parameters: domain_right_edge         = [5.20000000e+09 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2025-03-20 11:11:33,618 Parameters: cosmological_simulation   = 0
# Successfully created/updated 's15_a1.25_stir_output.mod'
