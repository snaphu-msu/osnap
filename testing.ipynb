# %%
from stir_to_mesa import *
convert("s15", 1.25, 0.85)
# Out:
# yt : [WARNING  ] 2025-03-20 16:57:10,835 Extending phi dimension to 2PI + left edge.
# yt : [WARNING  ] 2025-03-20 16:57:10,837 Extending theta dimension to PI + left edge.
# yt : [INFO     ] 2025-03-20 16:57:10,891 Parameters: current_time              = 1.2900000129797926
# yt : [INFO     ] 2025-03-20 16:57:10,892 Parameters: domain_dimensions         = [240   1   1]
# yt : [INFO     ] 2025-03-20 16:57:10,892 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-20 16:57:10,893 Parameters: domain_right_edge         = [2.00000000e+09 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2025-03-20 16:57:10,893 Parameters: cosmological_simulation   = 0
# cr56 missing from the STIR profiles. Filling with 1e-99.
# Successfully created/updated './output/s15_a1.25_stir_output'
