# %%
from osnap import *

# %%
save_data.convert(model_name = "15m1_0.0beta_p20", stir_alpha = 1.25, stir_portion = 0.8, plotted_profiles=["DEFAULT"])
# Out:
# Loading STIR checkpoint file and converting to dataframe.
# yt : [WARNING  ] 2025-10-22 12:38:44,281 Extending phi dimension to 2PI + left edge.
# yt : [WARNING  ] 2025-10-22 12:38:44,282 Extending theta dimension to PI + left edge.
# yt : [INFO     ] 2025-10-22 12:38:44,314 Parameters: current_time              = 1.7310003209834803
# yt : [INFO     ] 2025-10-22 12:38:44,315 Parameters: domain_dimensions         = [240   1   1]
# yt : [INFO     ] 2025-10-22 12:38:44,315 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-10-22 12:38:44,316 Parameters: domain_right_edge         = [5.00000000e+09 3.14159265e+00 6.28318531e+00]
# yt : [INFO     ] 2025-10-22 12:38:44,316 Parameters: cosmological_simulation   = 0
# Pulling composition from STIR data.
# Adjusting and calculating additional values.
# Columns in STIR data but missing from progenitor data: []
# Successfully created/updated '../output/15m1_0.0beta_p20_a1.25_stir_output.mod'
